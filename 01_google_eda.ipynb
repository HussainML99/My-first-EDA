# %% [markdown]
# # **Google Play Store Data⤵️**
# **Comprehensive Exploratory Data Analysis**
#
#
# **codanics** 🌏:[link](https://codanics.com/)

# %% [markdown]
# ### **01_About the Author💁🏾‍♂️**
#
# Hi there! I'm `Hussain`, and I'm learning about data science. I'm exploring different ideas and methods to improve my skills. Join me on this exciting journey as we learn and grow in data science together.

# %% [markdown]
# **Get in Touch with the Author**

# %% [markdown]
# <a href="mailto:hazrathussainpak99@gmail.com">
#   <img src="https://cdn4.iconfinder.com/data/icons/social-media-logos-6/512/112-gmail_email_mail-512.png" alt="Email" style="width: 33px; height: 33px;">
# </a>
#
#
#
#  <a href="https://www.linkedin.com/feed/">
#   <img src="https://cdn1.iconfinder.com/data/icons/logotypes/32/circle-linkedin-512.png" alt="Linkedin" style="width: 34px; height: 34px;">
# </a>
#
#
#   <a href="https://www.kaggle.com/hussain99">
#   <img src="https://upload.wikimedia.org/wikipedia/commons/7/7c/Kaggle_logo.png?20140912155123" alt="Kaggle" style="width: 35px; height: 35px;">
# </a>
#
#
#   <a href="https://github.com/dashboard">
#   <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png" alt="Github" style="width: 30px; height: 35px;">
# </a>

# %% [markdown]
# ### **02_About Dataset📑**
#
# - `Description`\
# The Data Set was downloaded from Kaggle, from the following [link](https://www.kaggle.com/datasets/lava18/google-play-store-apps/)
#
# - `Context`
# While many public datasets (on Kaggle and the like) provide Apple App Store data, there are not many counterpart datasets available for Google Play Store apps anywhere on the web. On digging deeper, I found out that iTunes App Store page deploys a nicely indexed appendix-like structure to allow for simple and easy web scraping. On the other hand, Google Play Store uses sophisticated modern-day techniques (like dynamic page load) using JQuery making scraping more challenging.
#
# - `Content`
# Each app (row) has values for catergory, rating, size, and more.
#
# - `Acknowledgements`
# This information is scraped from the Google Play Store. This app information would not be available without it.
#
# - `Inspiration`
# The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market!
#
#
#
# | #   | Name      | Define                                                                 |
# | --- | --------- | ---------------------------------------------------------------------- |
# | 1   | App       | Unique identifier for the app.                                        |
# | 2   | Category  | The primary genre or category of the app.                             |
# | 3   | Rating    | The average user rating of the app.                                   |
# | 4   | Reviews   | The number of user reviews for the app.                               |
# | 5   | Size      | The size of the app in bytes.                                         |
# | 6   | Installs  | The number of times the app has been installed.                        |
# | 7   | Type      | Indicates whether the app is free or paid.                           |
# | 8   | Price     | The price of the app (if not free).                                   |
# | 9   | Content Rating | The age rating or content restrictions for the app.              |
# | 10  | Genres    | Additional categories or genres associated with the app.              |
# | 11  | Last Updated | The date of the last update to the app.                            |
# | 12  | Current Ver | The current version of the app.                                     |
# | 13  | Android Ver | The minimum Android version required to run the app.                |

# %% [markdown]
# ### **03_Task**
#
# - We plan to perform Exploratory Data Analysis (EDA) on the dataset.
# - This analysis will assist us in cleaning and organizing the data.
# - We will document our observations while coding.
# - At the end, we will create a summary of our findings.
# - We will draw conclusions based on what we discovered.
#
#
# ### **04_Objective**
#
# - The main goal of the project is to analyze the dataset carefully.
# - We aim to find important information from the analysis.
# - We want to show developers and other key people how customers behave.
# - We will highlight customer needs.
# - This information will help attract more business for future apps.
#
#
# ### **05_Version of the Kernel Being Used**
# - Python 3.13.1

# %% [markdown]
# ### **06_Importing Libraries📥**

# %%
import pandas as pd  # for data manipulation and analysis
import numpy as np # for numerical computations like log,exp,sqrt etc
import matplotlib.pyplot as plt # for data visualization 
import seaborn as sns # for statistical data visualization 
#this is for jupyter notebook to show the plot in the notebook itself instead of opening a new window for the plot
# %matplotlib inline 

# By using these commands we can seee full display of columns and rows data 
pd.set_option('display.max_columns', None) # this is to display all the columns in the dataframe
pd.set_option('display.max_rows', None) # this is to display all the rows in the dataframe

# hide all warnings runtime
import warnings
warnings.filterwarnings('ignore') # this is to ignore all the warnings in the code

# %% [markdown]
# ---
# ---
#
# ## **Automatic EDA using `ydata_profiling`**
#
# #### Step 1: Install ydata_profiling
# - You can install ydata_profiling using pip. Open your terminal or command prompt and run:
#  pip install ydata-profiling

# %%
#  pip install ydata-profiling

# %% [markdown]
# #### Step 2: Import the Library and dataset

# %%
# # improt libraries
# import pandas as pd
# import seaborn as sns
# import ydata_profiling as yd

# # import the data
# df=pd.read_csv('googleplaystore.csv')

# # ydata profile report
# profile = yd.ProfileReport(df)
# profile.to_file(output_file='googleplaystore.csv.html')

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### **07_Loading, exploring, and cleaning the data**
#
# - Load the CSV file using pandas.
# - Create a dataframe and understand the data in the dataset with pandas.
# - Handle missing data, outliers, and incorrect records.

# %% [markdown]
# ### **08_let's load the dataset and assing it to a variable called `df`**

# %%
# import the data
df=pd.read_csv('googleplaystore.csv')

# %% [markdown]
# ### **09_Look at the first five rows of the data**

# %%
# display the first 5 rows of the data
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ### **10_let's view columns name**

# %%
# See the names of the columns. You can also use df.columns to see the names of the columns
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# - Change all column names to use underscores instead of spaces and capital letters.

# %%
# Convert all columns to snake case
df.rename(lambda x: x.lower().strip().replace(' ', '_'), 
            axis='columns', inplace=True)

# check the result
df.columns
# Out:
# Index(['app', 'category', 'rating', 'reviews', 'size', 'installs', 'type',
#        'price', 'content_rating', 'genres', 'last_updated', 'current_ver',
#        'android_ver'],
#       dtype='object')

# %% [markdown]
# ### **11_Let's have a look on the shape of the dataset**

# %%
# shape of the data
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# | **Rows** | **Columns** |
# |----------|-------------|
# | 10841    | 13          |
#
#
# - Not enough, let's have a look on the columns and their data types using detailed info function

# %%
# Let's take a quick look at the data.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app             10841 non-null  object
#  1   category        10840 non-null  object
#  2   rating          9367 non-null   float64
#  3   reviews         10841 non-null  int64
#  4   size            10841 non-null  object
#  5   installs        10841 non-null  object
#  6   type            10840 non-null  object
#  7   price           10841 non-null  object
#  8   content_rating  10841 non-null  object
#  9   genres          10840 non-null  object
#  10  last_updated    10841 non-null  object
#  11  current_ver     10833 non-null  object
#  12  android_ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ---
# ### **Observations_1**
#
# 1. There are `10841` rows and `13` columns in the dataset
# 2. The columns are of different data types
# 3. The columns in the datasets are:
#    - `'App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'`
# 4. There are some `missing values` in the dataset which we will read in details and deal later on in the notebook.
# 5. There are some columns which are of object data type but they should be of numeric data type, we will convert them later on in the notebook.
#    - `'Size', 'Installs', 'Price'`
#
# ---

# %% [markdown]
# ### **12_Descriptive Statistics**
#
# - We use descriptive statistics to `summarize` and `understand` the main characteristics of the dataset

# %%
# statistical summary of the data
df.describe()
# Out:
#             rating       reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %% [markdown]
# ---
# ### **Observations_2**
#
# We have only 2 columns with numeric data; the rest are considered object data in Python. However, `Size`, `Installs`, and `Price` are also numeric, so we need to convert them to numeric data during data cleaning
#
# ---

# %% [markdown]
# - Let's clean the `Size` column first

# %%
# check for null values
df['size'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - No null values, we are good to go.

# %%
# check unique values
print('Total number of unique values:', df['size'].nunique())
df['size'].unique()
# Out:
# Total number of unique values: 461
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %% [markdown]
# - There are many unique values in the Size column. First, we need to change the units from `M (megabytes)` and `K (kilobytes)` to bytes. After that, we will remove the M and K from the values and convert them into numbers
#
# - let's we firts chek  value_counts with `M` and `K` and `Varies with device`

# %%
# find the values in size column which has 'M' in it
df['size'].loc[df['size'].str.contains('M')].value_counts().sum()
# Out:
# np.int64(8830)

# %%
# find the values in size column which has 'k' in it
df['size'].loc[df['size'].str.contains('k')].value_counts().sum()
# Out:
# np.int64(316)

# %%
# find the values in size column which has 'Varies with device' in it
df['size'].loc[df['size'].str.contains('Varies with device')].value_counts().sum()
# Out:
# np.int64(1695)

# %% [markdown]
# - let's Add up all the values in the size column that say `M`, `K`, or `varies with device`

# %%
# Add the value K, M and Varies with device
8830+316+1695       # 8830 rows have 'M' in it
                    # 316 rows have 'k' in it
                    # 1695 rows have 'Varies with device' in it
# Out:
# 10841

# %% [markdown]
# - let's check the total values (entries) in Size column

# %%
# Calculate the total number of size entries
print(f"Total size entries: {df['size'].value_counts().sum()}")
# Out:
# Total size entries: 10841

# %% [markdown]
# ---
# ### **Observations_3**
#
#
# | Unit                     | Count |
# |--------------------------|-------|
# | M                        | 8830  |
# | K                        | 316   |
# | Varies with device       | 1695  |
#
#
# - Let's convert the `M` and `K` units into bytes and then remove the `M` and `K` from the values and convert them into numeric data type.
#
# ---

# %%
# convert the size column to numeric by multiplying the values with 1024 if it has 'k' in it and 1024*1024 if it has 'M' in it
# this function will convert the size column to numeric
def convert_size(size):
    # add function details here
    '''
    This function will convert the size column to numeric by multiplying the values with 1024 if it has 'k' in it and 1024*1024 if it has 'M' in it
    '''
    
    if isinstance(size, str):
        if 'k' in size:
            return float(size.replace('k', '')) * 1024
        elif 'M' in size:
            return float(size.replace('M', '')) * 1024 * 1024
        elif 'Varies with device' in size:
            return np.nan
    return size

df['size'] = df['size'].apply(convert_size)

# %% [markdown]
# - let's change the name `size` to `size_in_bytes`

# %%
# rename the column name 'Size' to 'Size_in_bytes'
df.rename(columns={'size': 'size_in_bytes'}, inplace=True)

# %% [markdown]
# - let's we make a new columns `size_in_mb`

# %%
# making a new column called 'Size in Mb' which will have the size in MB
df['size_in_mb'] = df['size_in_bytes'].apply(lambda x: x/(1024*1024))

# %% [markdown]
# ---
#
# - Now we have converted every value into bytes and removed the `M` and `K` from the values and converted them into numeric data type.
# - `Varies with device` was a string value, therefore we intentionally converted them into null values, which we can fill later on according to our needs.
# ---

# %% [markdown]
# - Let's have a look on the `Installs` column

# %%
# check the unique values in installs column
print('Total number of unique values in installs columns:', df['installs'].nunique())
df['installs'].unique()
# Out:
# Total number of unique values in installs columns: 21
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
# let's have a values counts
df['installs'].value_counts()
# Out:
# installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %% [markdown]
# - let's Determine the number of values that include a '+'

# %%
# find how many values has '+' in it
df['installs'].loc[df['installs'].str.contains('\+')].value_counts().sum()
# Out:
# np.int64(10840)

# %% [markdown]
# - let's check the total values (entries) in installs column

# %%
# Total values in Installs column
df['installs'].value_counts().sum()
# Out:
# np.int64(10841)

# %% [markdown]
# ---
# ### **Observations_4**
#
# - The total values in the `Installs` column are `10841` and there are no null values in the column.
# - However, one value 0 has no plus sign
#
# - Let's remove the plus sign `+` and `,` from the values and convert them into numeric data type
# -  The only problem I see here is the `+` sign in the values, let's remove them and convert the column into numeric data type.
#
# ---

# %%
# remove the plus sign from install column and convert it to numeric
df['installs'] = df['installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
# also remove the commas from the install column
df['installs'] = df['installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)
# convert the install column to numeric (integers because this is the number of installs/count)
df['installs'] = df['installs'].apply(lambda x: int(x))

# %% [markdown]
# - Let's verify if the dtypes has been changes and the `+` and `,` sign has been removed

# %%
# Beast way to check top 5 row
df.head(5)
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    reviews  size_in_bytes  installs  type price content_rating  \
# 0      159     19922944.0     10000  Free     0       Everyone
# 1      967     14680064.0    500000  Free     0       Everyone
# 2    87510      9122611.2   5000000  Free     0       Everyone
# 3   215644     26214400.0  50000000  Free     0           Teen
# 4      967      2936012.8    100000  Free     0       Everyone
#
#                       genres      last_updated         current_ver  \
# ...

# %% [markdown]
# - let's check up the data type of install columns

# %%
# check up data type 
df['installs'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# - We can generate a new columns based on the installation values, which will be helpful in our analysis

# %%
# maximum value instaalls coluns
df['installs'].max()
# Out:
# np.int64(1000000000)

# %%
# making a new column called 'Installs_category' which will have the category of the installs
bins = [-1, 0, 10, 1000, 10000, 100000, 1000000, 10000000, 10000000000]
labels=['no', 'Very low', 'Low', 'Moderate', 'More than moderate', 'High', 'Very High', 'Top Notch']
df['installs_category'] = pd.cut(df['installs'], bins=bins, labels=labels)

# %%
# check the value counts of the new column
df['installs_category'].value_counts()
# Out:
# installs_category
# Low                   2162
# High                  2118
# Very High             2004
# More than moderate    1648
# Moderate              1531
# Top Notch              828
# Very low               535
# no                      15
# Name: count, dtype: int64

# %%
# columns name
df.columns
# Out:
# Index(['app', 'category', 'rating', 'reviews', 'size_in_bytes', 'installs',
#        'type', 'price', 'content_rating', 'genres', 'last_updated',
#        'current_ver', 'android_ver', 'size_in_mb', 'installs_category'],
#       dtype='object')

# %% [markdown]
# - Let's have a look on the `Price` column

# %%
# check the unique values in installs column
print('Total number of unique values in price columns:', df['price'].nunique())
df['price'].unique()
# Out:
# Total number of unique values in price columns: 92
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
# ...

# %%
# we cheack the NaN value in parice
df['price'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - no null value they are good to go

# %%
# check the value counts of the 'Price' column
df['price'].value_counts()
# Out:
# price
# 0          10041
# $0.99        148
# $2.99        129
# $1.99         73
# $4.99         72
# $3.99         63
# $1.49         46
# $5.99         30
# $2.49         26
# $9.99         21
# $6.99         13
# $399.99       12
# $14.99        11
# $4.49          9
# $29.99         7
# $3.49          7
# $7.99          7
# $24.99         7
# $5.49          6
# $19.99         6
# $6.49          5
# $8.99          5
# $12.99         5
# $11.99         5
# $10.00         3
# $1.00          3
# $16.99         3
# $2.00          3
# $17.99         2
# $10.99         2
# $9.00          2
# $79.99         2
# $7.49          2
# $3.95          2
# $33.99         2
# $1.70          2
# $13.99         2
# $8.49          2
# $39.99         2
# $1.50          1
# $25.99         1
# $74.99         1
# $15.99         1
# $3.88          1
# $1.76          1
# $3.02          1
# $400.00        1
# $4.84          1
# $2.50          1
# $1.59          1
# $1.61          1
# $4.77          1
# ...

# %% [markdown]
# - We need to confirm if the values in the `Price` column are only with $ sign or not

# %%
# count the values having $ in the 'Price' column
df['price'].loc[df['price'].str.contains('\$')].value_counts().sum()
# Out:
# np.int64(800)

# %%
# This code counts the number of values in the 'Price' column which contains 0 but does not contain $ sign
df['price'].loc[(df['price'].str.contains('0')) & (~df['price'].str.contains('\$'))].value_counts().sum()
# Out:
# np.int64(10041)

# %% [markdown]
# ---
# ### **Observations_5**
#
# - Now we can confirm that the only currency used is `$` in the `Price` column or 0 value, as `800+10041=10841 Total values`
# - The only problem is $ sign let's remove it and convert the column into numeric data type.
#
#
# ---

# %%
# remove the dollar sign from the price column and convert it to numeric
df['price'] = df['price'].apply(lambda x: x.replace('$', '') if '$' in str(x) else x)
# convert the price column to numeric (float because this is the price)
df['price'] = df['price'].apply(lambda x: float(x))

# %%
# this will show the data type of the column
df['price'].dtype
# Out:
# dtype('float64')

# %%
# using f string to print the min, max and average price of the apps
print(f"Min price is: {df['price'].min()} $")
print(f"Max price is: {df['price'].max()} $")
print(f"Average price is: {df['price'].mean()} $")
# Out:
# Min price is: 0.0 $
# Max price is: 400.0 $
# Average price is: 1.0272733142699015 $

# %% [markdown]
# ### **13_Descriptive Statistics**

# %%
df.describe()
# Out:
#             rating       reviews  size_in_bytes      installs         price  \
# count  9367.000000  1.084100e+04   9.146000e+03  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05   2.255921e+07  1.546291e+07      1.027273
# std       0.515735  2.927629e+06   2.368595e+07  8.502557e+07     15.948971
# min       1.000000  0.000000e+00   8.704000e+03  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01   5.138022e+06  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   1.363149e+07  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04   3.145728e+07  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   1.048576e+08  1.000000e+09    400.000000
#
#         size_in_mb
# count  9146.000000
# mean     21.514141
# std      22.588679
# min       0.008301
# 25%       4.900000
# 50%      13.000000
# 75%      30.000000
# max     100.000000

# %% [markdown]
# ---
#
# ### **Observations_6**
# - Now, we have only 6 columns as numeric data type.
# - We can observe their descriptive statistics. and make tons of observations as per our hypotheses.
# - We can see that the `Rating` column has a minimum value of `1` and a maximum value of `5`, which is the range of rating, and the mean is `4.19` which is a good rating. On an average people give this rating.
# - We can see that the `Reviews` column has a minimum value of `0` and a maximum value of `78,158,306` 78+ Millions, which is the range of reviews, and the mean is `444,111.93` which is a good number of reviews. On an average people give this number of reviews to the apps. But it does not make sense to us, as we have different categories of apps.
# - Similarly, we can observe the other columns as well.
#
# Therefore, the most important thing is to classify as app based on the correlation matrix and then observe the descriptive statistics of the app category and number of installs, reviews, ratings, etc.
# But even before that we have to think about the missing values in the dataset.
#
# ---

# %% [markdown]
# ### **14_Dealing with the missing values🕵️**
#
# - Dealing with the missing values is one of the most important part of the data wrangling process, we must deal with the missing values in order to get the correct insights from the data.

# %% [markdown]
# - Let's have a look on the missing values in the dataset

# %%
# this will show the number of null values in each column
df.isnull().sum()
# Out:
# app                     0
# category                1
# rating               1474
# reviews                 0
# size_in_bytes        1695
# installs                0
# type                    1
# price                   0
# content_rating          0
# genres                  1
# last_updated            0
# current_ver             8
# android_ver             2
# size_in_mb           1695
# installs_category       0
# dtype: int64

# %%
# this will show the number of null values in each column in descending order
df.isnull().sum().sort_values(ascending=False)
# Out:
# size_in_bytes        1695
# size_in_mb           1695
# rating               1474
# current_ver             8
# android_ver             2
# type                    1
# category                1
# genres                  1
# installs                0
# app                     0
# reviews                 0
# last_updated            0
# content_rating          0
# price                   0
# installs_category       0
# dtype: int64

# %%
# this will show the total number of null values in the dataframe
df.isnull().sum().sum()
# Out:
# np.int64(4877)

# %%
# this will show the percentage of null values in each column
(df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
# Out:
# size_in_bytes        15.635089
# size_in_mb           15.635089
# rating               13.596532
# current_ver           0.073794
# android_ver           0.018448
# type                  0.009224
# category              0.009224
# genres                0.009224
# installs              0.000000
# app                   0.000000
# reviews               0.000000
# last_updated          0.000000
# content_rating        0.000000
# price                 0.000000
# installs_category     0.000000
# dtype: float64

# %% [markdown]
# | Column         | percentage of null values |
# |----------------|-------|
# | size_in_bytes  | 15.635089  |
# | size_in_mb     | 15.635089  |
# | rating         | 13.596532  |
# | current_ver    |  0.073794     |
# | android_ver    | 0.018448     |
# | type           | 0.009224     |
# | category       | 0.009224     |
# | genres         | 0.009224     |

# %% [markdown]
# - Let's plot the missing values in the dataset

# %%
# make a figure size
plt.figure(figsize=(16, 6))
#plot the null values in each column
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis') # this will show the heatmap of null values in the dataframe
# Out:
# <Axes: >

# %% [markdown]
# **Figure-1:** More missing values in the columns `size_in_bytes`, `size_in_mb`, and `rating`

# %% [markdown]
# - There is another way, let's plot the missing values by percentage

# %%
# make figure size
plt.figure(figsize=(16, 6))
# plot the null values by their percentage in each column
missing_percentage = df.isnull().sum()/len(df)*100
missing_percentage.plot(kind='bar')
# add the labels
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Percentage of Missing Values in each Column')
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column')

# %% [markdown]
# **Figure-2:** More % missing values in the columns `size_in_bytes`, `size_in_mb`, and `rating`

# %% [markdown]
# - We have some percentage columns, besides rating, with less than one percent of missing values. We will create a plot for them as follows

# %%
plt.figure(figsize=(16, 6)) # make figure size
missing_percentage[missing_percentage < 1].plot(kind='bar') # plot the null values by their percentage in each column
plt.xlabel('Columns') # add the x-axis labels
plt.ylabel('Percentage') # add the labels for y-axis
plt.title('Percentage of Missing Values in each Column without Rating column')  # add the title for the plot
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each Column without Rating column')

# %% [markdown]
# **Figure-3:** % missing values in the columns `'Current Ver'`:0.07%,`'Android Ver'`:0.01%, `'Type'`:0.01%, `'Category'`:0.01%, `'Genres'`:0.01%

# %% [markdown]
# ---
#
# ### **Observations_7**
# - We have 1695 missing values in the `'Size_in_bytes'` and `'Size_in_Mb'` columns, which is 15.6% of the total values in the column.
# - We have 1474 missing values in the `'Rating'` column, which is 13.6% of the total values in the column.
# - We have 8 missing value in the `'Current Ver'` column, which is 0.07% of the total values in the column.
# - We have 2 missing values in the `'Android Ver'` column, which is 0.01% of the total values in the column.
# - We have only 1 missing value in `Category`, `Type` and `Genres` columns, which is 0.009% of the total values in the column.
#
#
#
#
#    -   We can not impute the `Rating` column as is is directly linked with the installation column. To test this Hypothesis we need to plot the `Rating` column with the `Installs` and `Size` columns and statistically test it using `pearson correlation test`.
#
# ---

# %% [markdown]
# - Let's run the correlations

# %%
# these are numeric columns
df.describe()
# Out:
#             rating       reviews  size_in_bytes      installs         price  \
# count  9367.000000  1.084100e+04   9.146000e+03  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05   2.255921e+07  1.546291e+07      1.027273
# std       0.515735  2.927629e+06   2.368595e+07  8.502557e+07     15.948971
# min       1.000000  0.000000e+00   8.704000e+03  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01   5.138022e+06  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   1.363149e+07  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04   3.145728e+07  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   1.048576e+08  1.000000e+09    400.000000
#
#         size_in_mb
# count  9146.000000
# mean     21.514141
# std      22.588679
# min       0.008301
# 25%       4.900000
# 50%      13.000000
# 75%      30.000000
# max     100.000000

# %%
# Make a correlation matrix of numeric columns
plt.figure(figsize=(16, 10)) # make figure size  
numeric_cols = ['rating', 'reviews', 'size_in_bytes', 'installs', 'price', 'size_in_mb'] # make a list of numeric columns
sns.heatmap(df[numeric_cols].corr(), annot=True) # plot the correlation matrix
# Out:
# <Axes: >

# %%
# we can also calculate the correlation matrix using pandas
df[numeric_cols].corr() # this will show the correlation matrix
# Out:
#                  rating   reviews  size_in_bytes  installs     price  \
# rating         1.000000  0.068147       0.084098  0.051393 -0.021851
# reviews        0.068147  1.000000       0.238218  0.643123 -0.009666
# size_in_bytes  0.084098  0.238218       1.000000  0.164794 -0.023000
# installs       0.051393  0.643123       0.164794  1.000000 -0.011688
# price         -0.021851 -0.009666      -0.023000 -0.011688  1.000000
# size_in_mb     0.084098  0.238218       1.000000  0.164794 -0.023000
#
#                size_in_mb
# rating           0.084098
# reviews          0.238218
# size_in_bytes    1.000000
# installs         0.164794
# price           -0.023000
# size_in_mb       1.000000

# %%
# we can calculate the pearson correlation coefficient using scipy as well as follows

# this is to install scipy if you have not done it before
# pip install scipy 
from scipy import stats

# remove rows containing NaN or infinite values (Important to calculate Pearson's R)
df_clean = df.dropna()

# calculate Pearson's R between Rating and Installs
pearson_r, _ = stats.pearsonr(df_clean['reviews'], df_clean['installs'])
print(f"Pearson's R between Reviews and Installs: {pearson_r:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 5
#       1 # we can calculate the pearson correlation coefficient using scipy as well as follows
#       2
#       3 # this is to install scipy if you have not done it before
#       4 # pip install scipy
# ----> 5 from scipy import stats
#       7 # remove rows containing NaN or infinite values (Important to calculate Pearson's R)
#       8 df_clean = df.dropna()
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# ---
# ### **Observations_8**
# - Lighter color shows the high correlation and darker color shows the low correlation
# - We can see that the `Reviews` column has a high correlation with the `Installs` column, which is `0.64` according to corr(). Which is quite good.
#   - This shows that the more the reviews the more the installs are for one app. If in any case we need to impute reviews we have to think of number of install.
#     - If we have an ap with `2` installs and we imputer the reviews with `1000` or via average reviews then it will be wrong.
# - Installs is slightly correlated with `Size_in_Mb` or `Size_in_bytes` , which is `0.16`, this also shows us the importance of size and Installs. But we can not depend on it as the Peason correlation is very low.
# ---

# %% [markdown]
# - Before going ahead, let's remove the rows with missing values in the `Current Ver`, `Android Ver`, `Category`, `Type` and `Genres` columns, as they are very less in number and will not affect our analysis.

# %%
# length before removing null values
print(f"Length of the dataframe before removing null values: {len(df)}")
# Out:
# Length of the dataframe before removing null values: 10841

# %%
# remove the rows having null values in the 'Current Ver', 'Android Ver', 'Category', 'Type' and 'Genres' column
df.dropna(subset=['current_ver', 'android_ver', 'category', 'type', 'genres'], inplace=True)

# %%
# length after removing null values
print(f"Length of the dataframe after removing null values: {len(df)}")
# Out:
# Length of the dataframe after removing null values: 10829

# %% [markdown]
# - We have removed `12` rows having null values in the `Current Ver`, `Android Ver`, `Category`, `Type` and `Genres` columns.

# %%
# let's check the null values again
df.isnull().sum().sort_values(ascending=False)
# Out:
# size_in_bytes        1694
# size_in_mb           1694
# rating               1469
# category                0
# reviews                 0
# installs                0
# app                     0
# type                    0
# price                   0
# genres                  0
# content_rating          0
# last_updated            0
# current_ver             0
# android_ver             0
# installs_category       0
# dtype: int64

# %% [markdown]
# ---
# ## **Observations**
# - Only `Rating` and `Size_in_bytes` or `Size_in_Mb` columns are left with missing values.
#   - We know that we have to be carefull while deadling with `Rating` column, as it is directly linked with the `Installs` column.
#   - In Size columns we already know about `Varies with device` values, which we have converted into null values, we do not need to impute at the moment, as every app has different size and nobody can predict that as nearly as possible.
# ---

# %% [markdown]
# ```Dealing with size_in_bytes Column```

# %%
# total number of null values in size_in_bytes column
df['size_in_bytes'].isnull().value_counts()
# Out:
# size_in_bytes
# False    9135
# True     1694
# Name: count, dtype: int64

# %% [markdown]
# - We have 1694 Null Values in it

# %%
# fill the missing value by mean 
df['size_in_bytes'].fillna(df['size_in_bytes'].mean(),inplace=True)

# %% [markdown]
# ```Dealing with size_in_mb```

# %%
# total number of null values in size_in_mb column
df['size_in_mb'].isnull().value_counts()
# Out:
# size_in_mb
# False    9135
# True     1694
# Name: count, dtype: int64

# %% [markdown]
# - We have 1694 Null Values in it

# %%
# fill the missing value by mean 
df['size_in_mb'].fillna(df['size_in_mb'].mean(),inplace=True)

# %% [markdown]
# ```Dealing with rating```

# %%
# data types of rating
df['rating'].dtype
# Out:
# dtype('float64')

# %%
df['rating'].isnull().value_counts()
# Out:
# rating
# False    9360
# True     1469
# Name: count, dtype: int64

# %% [markdown]
# - we have 1469 Null values in it

# %%
# fill the missing value by median 
df['rating'].fillna(df['rating'].median(),inplace=True)

# %%
# let's check the null values again
df.isnull().sum()
# Out:
# app                  0
# category             0
# rating               0
# reviews              0
# size_in_bytes        0
# installs             0
# type                 0
# price                0
# content_rating       0
# genres               0
# last_updated         0
# current_ver          0
# android_ver          0
# size_in_mb           0
# installs_category    0
# dtype: int64

# %% [markdown]
# - Our data shines bright✨, completely cleansed of any null values🌝!

# %% [markdown]
# ### **15_Duplicates**
#
# * Removing duplicates is one of the most important part of the data wrangling process, we must remove the duplicates in order to get the correct insights from the data.
# * If you do not remove duplicates from a dataset, it can lead to incorrect insights and analysis.
# * Duplicates can skew statistical measures such as mean, median, and standard deviation, and can also lead to over-representation of certain data points.
# * It is important to remove duplicates to ensure the accuracy and reliability of your data analysis.

# %%
# find duplicate if any
df.duplicated().sum()
# Out:
# np.int64(483)

# %% [markdown]
# - This shows us total duplicates, but we can also check based on the app name, as we know that every app has a unique name.

# %%
# find duplicate if any in the 'App' column
df['app'].duplicated().sum()
# Out:
# np.int64(1181)

# %% [markdown]
# - Oops! we have 1181 dupicate app names
# - Can we find a column which can help us to remove the duplicates?
#
# let's check for number of duplicates in each column using a for loop and printing the output

# %%
# let's check for number of duplicates
for col in df.columns:
    print(f"Number of duplicates in {col} column are: {df[col].duplicated().sum()}")
# Out:
# Number of duplicates in app column are: 1181
# Number of duplicates in category column are: 10796
# Number of duplicates in rating column are: 10790
# Number of duplicates in reviews column are: 4830
# Number of duplicates in size_in_bytes column are: 10373
# Number of duplicates in installs column are: 10809
# Number of duplicates in type column are: 10827
# Number of duplicates in price column are: 10737
# Number of duplicates in content_rating column are: 10823
# Number of duplicates in genres column are: 10710
# Number of duplicates in last_updated column are: 9453
# Number of duplicates in current_ver column are: 7998
# Number of duplicates in android_ver column are: 10796
# Number of duplicates in size_in_mb column are: 10373
# Number of duplicates in installs_category column are: 10821

# %% [markdown]
# - This means that the only better way to find duplicates is to check for whole data

# %%
# print the number of duplicates in df
print(f"Number of duplicates in df are: {df.duplicated().sum()}")
# Out:
# Number of duplicates in df are: 483

# %% [markdown]
# - Find and watch all duplicates if they are real!

# %%
# find exact duplicates and print them
df[df['app'].duplicated(keep=False)].sort_values(by='app').head(10)
# Out:
#                                app            category  rating  reviews  \
# 1393         10 Best Foods for You  HEALTH_AND_FITNESS     4.0     2490
# 1407         10 Best Foods for You  HEALTH_AND_FITNESS     4.0     2490
# 2543    1800 Contacts - Lens Store             MEDICAL     4.7    23160
# 2322    1800 Contacts - Lens Store             MEDICAL     4.7    23160
# 2385    2017 EMRA Antibiotic Guide             MEDICAL     4.4       12
# 2256    2017 EMRA Antibiotic Guide             MEDICAL     4.4       12
# 1337  21-Day Meditation Experience  HEALTH_AND_FITNESS     4.4    11506
# 1434  21-Day Meditation Experience  HEALTH_AND_FITNESS     4.4    11506
# 3083       365Scores - Live Scores              SPORTS     4.6   666521
# 5415       365Scores - Live Scores              SPORTS     4.6   666246
#
#       size_in_bytes  installs  type  price content_rating            genres  \
# 1393      3984588.8    500000  Free   0.00   Everyone 10+  Health & Fitness
# ...

# %% [markdown]
# - let's remove Duplicates

# %%
# remove the duplicates
df.drop_duplicates(inplace=True)

# %%
# print the number of rows and columns after removing duplicates
print(f"Number of rows after removing duplicates: {df.shape[0]}")
# Out:
# Number of rows after removing duplicates: 10346

# %% [markdown]
# - Now we have removed 483 duplicates from the dataset. and have 10346 rows left.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### **15_Insights from Data**

# %% [markdown]
# - [Which category has the highest number of appss?](#Which-category-has-the-highest-number-of-appss?)
# - [Which category has the highest number of installs?](#Which-category-has-the-highest-number-of-installs?)
# - [Which category has the highest number of reviews?](#Which-category-has-the-highest-number-of-reviews?)
# - [Which category has the highest rating?](#Which-category-has-the-highest-rating?)
# - [Which type of apps are more in the dataset, free or paid?](#Which-type-of-apps-are-more-in-the-dataset-free-or-paid?)
# - [Which content rating is most popular in installs?](#Which-content-rating-is-most-popular-in-installs?)
# - [find how many apps are there in Everyone content rating?](#find-how-many-apps-are-there-in-Everyone-content-rating?)
# - [plot top 5 rated free apps?](#plot-top-5-rated-free-apps?)
# - [Plot top 5 FREE apps with highest number of reviews?](#Plot-top-5-FREE-apps-with-highest-number-of-reviews?)
# - [What is the Top 5 Paid Apps with Highest Number of Reviews?](#What-is-the-Top-5-Paid-Apps-with-Highest-Number-of-Reviews?)
# - [what is the Top 5 Rated Paid Apps?](#what-is-the-Top-5-Rated-Paid-Apps?)
# - [What is the correlation between the number of reviews and app ratings?](#What-is-the-correlation-between-the-number-of-reviews-and-app-ratings?)
# - [How does app size (in MB) affect user ratings?](#How-does-app-size-(in-MB)-affect-user-ratings?)
# - [Which apps have the highest ratings but the lowest number of installs?](#Which-apps-have-the-highest-ratings-but-the-lowest-number-of-installs?)
# - [How does the Android version requirement affect app ratings?](#How-does-the-Android-version-requirement-affect-app-ratings?)
# - [What is the average size in megabytes of apps for adults, kids, everyone, and tweens?](#What-is-the-average-size-in-megabytes-of-apps-for-adults-kids-everyone-and-tweens?)
# - [How do app prices affect their ratings?](#How-do-app-prices-affect-their-ratings?)
# - [Are free apps rated higher than paid ones?](#Are-free-apps-rated-higher-than-paid-ones?)
# - [Which genres have the highest and lowest ratings on average, and what could be the reason for this?](#Which-genres-have-the-highest-and-lowest-ratings-on-average-and-what-could-be-the-reason-for-this?)
# - [Between free and paid apps, which type has a higher average rating and more installs?](#Between-free-and-paid-apps-which-type-has-a-higher-average-rating-and-more-installs?)
# - [What is the average app size for the top 10 most installed apps in each category?](#What-is-the-average-app-size-for-the-top-10-most-installed-apps-in-each-category?)
# - [How do app ratings differ by content rating categories (e.g.Everyone vs. Mature)?](#How-do-app-ratings-differ-by-content-rating-categorie-e.g-Everyone-vs-Mature?)

# %% [markdown]
# ## **Question 1:**
# ### **Which category has the highest number of appss?**

# %%
# which category has highest number of apps
df['category'].value_counts().head(10) # this will show the top 10 categories with highest number of apps
# Out:
# category
# FAMILY             1939
# GAME               1121
# TOOLS               841
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     386
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: count, dtype: int64

# %% [markdown]
#  ### top 10 categories with highest number of apps
#
#  | Category          | Count |
# |-------------------|-------|
# | FAMILY            | 1939  |
# | GAME              | 1121  |
# | TOOLS             | 841   |
# | BUSINESS          | 427   |
# | MEDICAL           | 408   |
# | PRODUCTIVITY      | 407   |
# | PERSONALIZATION    | 386   |
# | LIFESTYLE         | 373   |
# | COMMUNICATION     | 366   |
# | FINANCE           | 360   |

# %% [markdown]
# ---

# %% [markdown]
# ## **Question 2:**
# ### **Which category has the highest number of installs?**

# %%
# category with highest number of Installs
df.groupby('category')['installs'].sum().sort_values(ascending=False).head(10)
# Out:
# category
# GAME                  31544024415
# COMMUNICATION         24152276251
# SOCIAL                12513867902
# PRODUCTIVITY          12463091369
# TOOLS                 11452271905
# FAMILY                10041632405
# PHOTOGRAPHY            9721247655
# TRAVEL_AND_LOCAL       6361887146
# VIDEO_PLAYERS          6222002720
# NEWS_AND_MAGAZINES     5393217760
# Name: installs, dtype: int64

# %%
# percentage category with highest number of Installs
(df.groupby('category')['installs'].sum() / df['installs'].sum() * 100).sort_values(ascending=False).head(10)
# Out:
# category
# GAME                  21.512618
# COMMUNICATION         16.471541
# SOCIAL                 8.534297
# PRODUCTIVITY           8.499668
# TOOLS                  7.810302
# FAMILY                 6.848264
# PHOTOGRAPHY            6.629766
# TRAVEL_AND_LOCAL       4.338725
# VIDEO_PLAYERS          4.243326
# NEWS_AND_MAGAZINES     3.678105
# Name: installs, dtype: float64

# %% [markdown]
# - GAME has the highest number of installs with 21.512618% installs.
#
# ---

# %% [markdown]
# ## **Question 3:**
# ### **Which category has the highest number of reviews?**

# %%
# Category with highest number of Reviews
df.groupby('category')['reviews'].sum().sort_values(ascending=False).head(10)
# Out:
# category
# GAME               1415536650
# COMMUNICATION       601273552
# SOCIAL              533576829
# FAMILY              396771746
# TOOLS               273181033
# PHOTOGRAPHY         204297410
# VIDEO_PLAYERS       110380188
# PRODUCTIVITY        102554498
# SHOPPING             94931162
# PERSONALIZATION      75192744
# Name: reviews, dtype: int64

# %%
# percentage category with highest number of Installs
(df.groupby('category')['reviews'].sum() / df['reviews'].sum() * 100).sort_values(ascending=False).head(10)
# Out:
# category
# GAME               33.671753
# COMMUNICATION      14.302657
# SOCIAL             12.692336
# FAMILY              9.438117
# TOOLS               6.498231
# PHOTOGRAPHY         4.859678
# VIDEO_PLAYERS       2.625643
# PRODUCTIVITY        2.439492
# SHOPPING            2.258153
# PERSONALIZATION     1.788630
# Name: reviews, dtype: float64

# %%
# Sort and select top 10
percentage_reviews=(df.groupby('category')['reviews'].sum() / df['reviews'].sum() * 100).sort_values(ascending=False).head(10)

# Sort and select top 10
top_10_percentage = percentage_reviews.sort_values(ascending=False).head(10)

# Set the style for the plot
sns.set(style="whitegrid")

# Create the horizontal bar chart
plt.figure(figsize=(12, 6))
bar_plot = sns.barplot(
    x=top_10_percentage.values, 
    y=top_10_percentage.index, 
    palette='viridis', 
    orient='h'
)

# Add data labels
for index, value in enumerate(top_10_percentage):
    bar_plot.text(value, index, f'{value:.2f}%', va='center')

# Set labels and title
plt.xlabel('Percentage of Total Reviews')
plt.title('Top 10 Categories by Percentage of Reviews', fontsize=16)
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# **Figure-3:**  The category with the highest percentage of installs is `GAME` accounting for approximately 33.67% of total installs. Following closely is `COMMUNICATION` with about 14.30% of installs

# %% [markdown]
# ---

# %% [markdown]
# ## **Question 4:**
# ### **Which category has the highest rating?**

# %%
# Category with highest average Rating
df.groupby('category')['rating'].mean().sort_values(ascending=False).head(10)
# Out:
# category
# EVENTS                 4.395313
# EDUCATION              4.375385
# ART_AND_DESIGN         4.373437
# BOOKS_AND_REFERENCE    4.336681
# PERSONALIZATION        4.326425
# PARENTING              4.300000
# BEAUTY                 4.283019
# GAME                   4.282070
# HEALTH_AND_FITNESS     4.266993
# SOCIAL                 4.260714
# Name: rating, dtype: float64

# %%
# plot the rating distribution
plt.figure(figsize=(16, 6)) # make figure size
sns.kdeplot(df['rating'], color="blue", shade=True) # plot the distribution plot
# Out:
# <Axes: xlabel='rating', ylabel='Density'>

# %% [markdown]
# **Figure-4:** The data shows EVENTS as the top-rated category at 4.44, followed by ART_AND_DESIGN and EDUCATION at 4.38. Categories like BOOKS_AND_REFERENCE and PERSONALIZATION also exceed 4.33, highlighting users' preference for creativity and learning.
#
# ---

# %% [markdown]
# ## **Question 5:**
# ### **Which type of apps are more in the dataset, free or paid?**

# %%
# plot number of installs for free vs paid apps make a bar plot
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='type', y='installs', data=df) # plot the bar plot

# show scatter plot as well where x-axis is Installs and y-axis is Price and hue is Type
plt.figure(figsize=(16, 6)) # make figure size
sns.scatterplot(x='installs', y='price', hue='type', data=df) # plot the scatter plot
# Out:
# <Axes: xlabel='installs', ylabel='price'>

# %% [markdown]
# **Figure-5:** The data shows that 92.61% of apps are free, while only 7.39% are paid. This indicates that the majority of apps in the dataset are free.
#
# ---

# %% [markdown]
# ## **Question 6:**
# ### **Which content rating is most popular in installs?**

# %%
# Which content rating is most popular in installs
df['content_rating'].value_counts() # this will show the value counts of each content rating
# Out:
# content_rating
# Everyone           8372
# Teen               1146
# Mature 17+          447
# Everyone 10+        376
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
# plot the bar plot of Content Rating vs Installs
plt.figure(figsize=(16, 6)) # make figure size
sns.barplot(x='content_rating', y='installs', data=df) # plot the bar plot
# Out:
# <Axes: xlabel='content_rating', ylabel='installs'>

# %% [markdown]
# **Figure-6:** The data shows that the most popular content rating is `Everyone` with 80.39% of installs, followed by `Teen` with 11.64% of installs. This indicates that the majority of apps in the dataset are for everyone.
#
# ---

# %% [markdown]
# ## **Question 7:**
# ### **find how many apps are there in Everyone content rating?**

# %%
df['category'].loc[df['content_rating'].str.lower() == 'everyone'].value_counts()
# Out:
# category
# FAMILY                 1498
# TOOLS                   833
# GAME                    595
# BUSINESS                412
# PRODUCTIVITY            396
# MEDICAL                 390
# FINANCE                 355
# LIFESTYLE               337
# COMMUNICATION           325
# SPORTS                  318
# PERSONALIZATION         318
# PHOTOGRAPHY             307
# HEALTH_AND_FITNESS      275
# TRAVEL_AND_LOCAL        230
# BOOKS_AND_REFERENCE     200
# SHOPPING                183
# NEWS_AND_MAGAZINES      168
# VIDEO_PLAYERS           146
# MAPS_AND_NAVIGATION     133
# EDUCATION               121
# FOOD_AND_DRINK          114
# SOCIAL                   98
# LIBRARIES_AND_DEMO       84
# AUTO_AND_VEHICLES        83
# WEATHER                  78
# HOUSE_AND_HOME           78
# ART_AND_DESIGN           60
# PARENTING                58
# EVENTS                   53
# BEAUTY                   45
# ENTERTAINMENT            37
# COMICS                   26
# ...

# %% [markdown]
# - There are 8714 apps in the Everyone content rating.The data shows that the `FAMILY` category has the highest number of apps (1,498), followed by `TOOLS` (833) and `GAME` (595), indicating a diverse range of applications across various categories.
#
# ---

# %% [markdown]
# ## **Question 8:**
# ### **plot top 5 rated free apps?**

# %%
# Set the style of seaborn
sns.set(style="whitegrid")

# Filter and sort the data
top_free_apps = df[df['type'] == 'Free'].sort_values(by='rating', ascending=False).head(5)

# Create the bar plot
plt.figure(figsize=(16, 6))
bar_plot = sns.barplot(x='app', y='rating', data=top_free_apps, palette='viridis')

# Add titles and labels
plt.title('Top 5 Rated Free Apps', fontsize=20, fontweight='bold')
plt.xlabel('App Name', fontsize=14)
plt.ylabel('Rating', fontsize=14)

# Rotate the x labels for better readability
plt.xticks(rotation=45, ha='right')

# Add data labels on top of the bars
for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.2f'), 
                      (p.get_x() + p.get_width() / 2., p.get_height()), 
                      ha='center', va='center', 
                      fontsize=12, color='black', 
                      xytext=(0, 5), 
                      textcoords='offset points')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure-8:** This plot show top 5 rated free apps
#
# ---

# %% [markdown]
# ## **Question 9:**
# ### **Plot top 5 FREE apps with highest number of reviews?**

# %%
# Set the aesthetic style of the plots
sns.set_theme(style="whitegrid")

# Prepare the data
top_free_apps = df[df['type'] == 'Free'].sort_values(by='reviews', ascending=False).head(5)

# Create the bar plot
plt.figure(figsize=(16, 6))
barplot = sns.barplot(x='app', y='reviews', data=top_free_apps, palette='viridis')

# Add title and labels
plt.title('Top 5 Free Apps with Highest Number of Reviews', fontsize=20)
plt.xlabel('Apps', fontsize=15)
plt.ylabel('Number of Reviews', fontsize=15)

# Add data labels on top of the bars
for p in barplot.patches:
    barplot.annotate(f'{int(p.get_height()):,}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha='center', va='baseline', fontsize=12, color='black', xytext=(0, 5), 
                     textcoords='offset points')

# Show the grid
plt.grid(axis='y')

# Show the plot
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure-9:**  Free apps with the highest number of reviews are `Facebook`, `WhatsApp Messenger`, `Instagram`
#
# ---

# %% [markdown]
# ## **Question 10:**
# ### **What is the Top 5 Paid Apps with Highest Number of Reviews?**

# %%
# Set the aesthetic style of the plots
sns.set_theme(style="whitegrid")

# Prepare the data
top_paid_apps = df[df['type'] == 'Paid'].sort_values(by='reviews', ascending=False).head(5)

# Create the bar plot
plt.figure(figsize=(16, 6))
barplot = sns.barplot(x='app', y='reviews', data=top_paid_apps, palette='rocket')

# Add title and labels
plt.title('Top 5 Paid Apps with Highest Number of Reviews', fontsize=20)
plt.xlabel('Apps', fontsize=15)
plt.ylabel('Number of Reviews', fontsize=15)

# Add data labels on top of the bars
for p in barplot.patches:
    barplot.annotate(f'{int(p.get_height()):,}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha='center', va='baseline', fontsize=12, color='black', xytext=(0, 5), 
                     textcoords='offset points')

# Show the grid
plt.grid(axis='y')

# Show the plot
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure-10:** This plots show the top 5 free apps with the highest number of review `Minecraft`,`Hitman Sniper`,`Grand Theft Auto`,`Bloons TD 5`
#
#
# ---

# %% [markdown]
# ## **Question 11:**
# ### **what is the Top 5 Rated Paid Apps?**

# %%
# Set the aesthetic style of the plots
sns.set_theme(style="whitegrid")

# Prepare the data
top_rated_paid_apps = df[df['type'] == 'Paid'].sort_values(by='rating', ascending=False).head(5)

# Create the bar plot
plt.figure(figsize=(16, 6))
barplot = sns.barplot(x='app', y='rating', data=top_rated_paid_apps, palette='magma')

# Add title and labels
plt.title('Top 5 Rated Paid Apps', fontsize=20)
plt.xlabel('Apps', fontsize=15)
plt.ylabel('Rating', fontsize=15)

# Add data labels on top of the bars
for p in barplot.patches:
    barplot.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha='center', va='baseline', fontsize=12, color='black', xytext=(0, 5), 
                     textcoords='offset points')

# Show the grid
plt.grid(axis='y')

# Show the plot
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure-11:** This plots show the top 5 free apps with the highest number of rating `Mu.F.O`,`FO Bixby`,`Morse Player`,`Santa's Monster Shootout DX`,`Chronolink DX`
#
#
# ---

# %% [markdown]
# ## **Question 12:**
# ### **What is the correlation between the number of reviews and app ratings?**

# %%
# Calculate the correlation
correlation_reviews = df['reviews'].corr(df['rating'])
print(f"Correlation between number of reviews and app ratings: {correlation_reviews:.2f}")
# Out:
# Correlation between number of reviews and app ratings: 0.06

# %%
# Visualize the relationship
plt.figure(figsize=(10, 6))
sns.scatterplot(x='reviews', y='rating', data=df)
plt.title('Scatter Plot of Reviews vs. Ratings', fontsize=16)
plt.xlabel('Number of Reviews', fontsize=14)
plt.ylabel('App Rating', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure-12:** The data points are likely scattered, showing that other factors may influence app ratings more than the number of reviews.
#
# ---

# %% [markdown]
# ## **Question 13:**
# ### **How does app size (in MB) affect user ratings?**

# %%
# Calculate the correlation
correlation_rating = df['size_in_mb'].corr(df['rating'])
print(f"Correlation between app size and user ratings: {correlation_rating:.2f}")
# Out:
# Correlation between app size and user ratings: 0.06

# %% [markdown]
# - the correlation of 0.06 suggests that app size has a minimal impact on user ratings

# %%
# Visualize the relationship
plt.figure(figsize=(10, 6))
sns.scatterplot(x='size_in_mb', y='rating', data=df)
plt.title('App Size vs. User Ratings', fontsize=16)
plt.xlabel('App Size (MB)', fontsize=14)
plt.ylabel('User Rating', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure-13:** The data points are likely scattered, showing that other factors may influence app ratings more than the app size.
#
# ---

# %% [markdown]
# ## **Question 14:**
# ### **Which apps have the highest ratings but the lowest number of installs?**

# %%
# Sort by rating and installs columns
top_apps = df.sort_values(by=['rating', 'installs'], ascending=[False, True])

# Select the top X apps with highest ratings and lowest installs
# Change the number in head() to get more results
result = top_apps.head(10)

# Display the result
print(result[['app', 'rating', 'installs']])
# Out:
#                                                    app  rating  installs
# 2454                               KBA-EZ Health Guide     5.0         1
# 5917                                          Ra Ga Ba     5.0         1
# 10697                                          Mu.F.O.     5.0         1
# 2450                                   Tablet Reminder     5.0         5
# 2459   Anatomy & Physiology Vocabulary Exam Review App     5.0         5
# 2484                                 Clinic Doctor EHr     5.0         5
# 6700                                  Brick Breaker BR     5.0         5
# 7147                                         CB Heroes     5.0         5
# 7731                                           CQ ESPM     5.0         5
# 8146                                           CZ-Help     5.0         5

# %% [markdown]
# | App                                                        | Rating | Installs |
# |-----------------------------------------------------------|--------|----------|
# | KBA-EZ Health Guide                                       | 5.0    | 1        |
# | Ra Ga Ba                                                  | 5.0    | 1        |
# | Mu.F.O.                                                  | 5.0    | 1        |
# | Tablet Reminder                                           | 5.0    | 5        |
# | Anatomy & Physiology Vocabulary Exam Review App          | 5.0    | 5        |
# | Clinic Doctor EHr                                        | 5.0    | 5        |
# | Brick Breaker BR                                         | 5.0    | 5        |
# | CB Heroes                                                | 5.0    | 5        |
# | CQ ESPM                                                  | 5.0    | 5        |
# | CZ-Help                                                  | 5.0    | 5        |
#
#
#
# - The dataset shows several apps that all have a perfect rating of 5.0 but very low install counts, with the highest being only 5 installs.
#
# ---

# %% [markdown]
# ## **Question 15:**
# ### **How does the Android version requirement affect app ratings?**

# %%
# Group by major Android version and calculate average rating
average_ratings = df.groupby('android_ver')['rating'].mean().reset_index()

# Sort values for better visualization
average_ratings = average_ratings.sort_values(by='android_ver')
# Change the number in head() to get more results
average_ratings.head(15)
# Out:
#       android_ver    rating
# 0      1.0 and up  4.050000
# 1      1.5 and up  4.100000
# 2      1.6 and up  4.139130
# 3      2.0 and up  4.361290
# 4    2.0.1 and up  4.328571
# 5      2.1 and up  4.170677
# 6     2.2 - 7.1.1  4.300000
# 7      2.2 and up  4.025941
# 8      2.3 and up  4.127103
# 9    2.3.3 and up  4.092832
# 10     3.0 and up  4.140254
# 11     3.1 and up  4.030000
# 12     3.2 and up  4.030556
# 13     4.0 and up  4.190262
# 14  4.0.3 - 7.1.1  4.150000

# %% [markdown]
# - The data shows a clear trend: as the Android version requirement goes up, average app ratings also increase. Interestingly, the highest ratings come from the earliest versions, which support more devices, showing a strong link between version support and user satisfaction.

# %%
# Visualize the relationship
plt.figure(figsize=(10, 5))
sns.barplot(x='android_ver', y='rating', data=average_ratings.head(15), palette='viridis')
plt.title('Average App Ratings by Android Version', fontsize=16)
plt.xlabel('android_ver', fontsize=14)
plt.ylabel('Average Rating', fontsize=14)
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure-14:** This graph show android_ver increases, the average rating also increases, indicating a positive correlation between the two
# variables.
#
# ---

# %% [markdown]
# ## **Question 16:**
# ### **What is the average size in megabytes of apps for adults, kids, everyone, and tweens?**

# %%
# Group by Content_Rating and get mean of size_in_mb
average_sizes=df.groupby(['content_rating'])['size_in_mb'].mean().reset_index()
average_sizes
# Out:
#     content_rating  size_in_mb
# 0  Adults only 18+   22.478199
# 1         Everyone   19.377462
# 2     Everyone 10+   37.035657
# 3       Mature 17+   24.830839
# 4             Teen   29.191413
# 5          Unrated    4.450000

# %%
# Group by content_rating and calculate the average size in MB
average_sizes = df.groupby(['content_rating'])['size_in_mb'].mean().reset_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=average_sizes, x='content_rating', y='size_in_mb', palette='viridis')
plt.title('Average App Size by Content Rating', fontsize=16)
plt.xlabel('Content Rating', fontsize=14)
plt.ylabel('Average Size (MB)', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure-15:** The `Everyone 10+` category has the largest average size among the groups.
#
# ---

# %% [markdown]
# ## **Question 17:**
# ### **How do app prices affect their ratings?**

# %%
# Calculate correlation
correlation_price_rating = df['price'].corr(df['rating'])
print(f'Correlation between price and rating: {correlation_price_rating:.2f}')
# Out:
# Correlation between price and rating: -0.02

# %%
# Create a scatter plot to visualize the relationship between price and rating
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='price', y='rating', alpha=0.6)
plt.title('App Prices vs. Ratings')
plt.xlabel('Price ($)')
plt.ylabel('Rating')
plt.xscale('log')  # Use log scale if there are large price variations
plt.grid(True)
plt.show()

# %% [markdown]
# **Figure 16:** Changes in app prices do not appear to significantly affect their ratings.
#
# ---

# %% [markdown]
# ## **Question 18:**
# ### **Are free apps rated higher than paid ones?**

# %%
# Create a new DataFrame to calculate average ratings for free and paid apps
avg_ratings = df.groupby('type')['rating'].mean().reset_index()

# Plotting the bar graph
plt.figure(figsize=(8, 5))
plt.bar(avg_ratings['type'], avg_ratings['rating'], color=['blue', 'green'])
plt.title('Average Ratings: Free Apps vs. Paid Apps')
plt.xlabel('App Type')
plt.ylabel('Average Rating')
plt.ylim(0, 5)  # Assuming rating is out of 5
plt.xticks(rotation=45)

# Add the average rating values on top of the bars
for index, value in enumerate(avg_ratings['rating']):
    plt.text(index, value + 0.05, f"{value:.2f}", ha='center')

plt.grid(axis='y')
plt.show()

# %% [markdown]
# **Figure-17:** The difference in average ratings is approximately 0.07, indicating that, on average, paid apps are rated slightly higher than free apps
#
# ---

# %% [markdown]
# ## **Question 19:**
# ### **Which genres have the highest and lowest ratings on average, and what could be the reason for this?**

# %%
# Assuming the dataset has 'genre' and 'rating' columns
# Split genres if they are in a single string
df['genre'] = df['genres'].str.split(',')

# Explode the dataframe so that each genre has its own row
df_exploded = df.explode('genres')

# Calculate average ratings by genre
average_ratings = df_exploded.groupby('genres')['rating'].mean().reset_index()

# Find genres with highest and lowest average ratings
highest_rated = average_ratings.loc[average_ratings['rating'].idxmax()]
lowest_rated = average_ratings.loc[average_ratings['rating'].idxmin()]

print("Highest Rated Genre:")
print(highest_rated)

print("\nLowest Rated Genre:")
print(lowest_rated)
# Out:
# Highest Rated Genre:
# genres    Board;Pretend Play
# rating                   4.8
# Name: 18, dtype: object
#
# Lowest Rated Genre:
# genres    Parenting;Brain Games
# rating                      3.8
# Name: 77, dtype: object

# %% [markdown]
# | Genre                     | Rating |
# |---------------------------|--------|
# | Board; Pretend Play       | 4.8    |
# | Parenting; Brain Games    | 3.8    |
#
#
# - The different ratings show that players like different things in games. Games that are fun and encourage creativity usually get better ratings. On the other hand, games that feel more like learning or are serious might not attract as many players.
#
#
# ---

# %% [markdown]
# ## **Question 20:**
# ### **Between free and paid apps, which type has a higher average rating and more installs?**

# %%
# Filter the DataFrame to include only free apps
free_apps = df[df['type'] == 'Free']

# Filter the DataFrame to include only paid apps
paid_apps = df[df['type'] == 'Paid']

# Calculate the average rating for free apps
free_avg_rating = free_apps['rating'].mean()

# Calculate the total number of installs for free apps
free_total_installs = free_apps['installs'].sum()

# Calculate the average rating for paid apps
paid_avg_rating = paid_apps['rating'].mean()

# Calculate the total number of installs for paid apps
paid_total_installs = paid_apps['installs'].sum()

# Print results
print("Free Apps - Average Rating:", free_avg_rating, "| Total Installs:", free_total_installs)
print("Paid Apps - Average Rating:", paid_avg_rating, "| Total Installs:", paid_total_installs)

# Determine which type is better
if free_avg_rating > paid_avg_rating:
    print("Free apps have a higher average rating.")
else:
    print("Paid apps have a higher average rating.")

if free_total_installs > paid_total_installs:
    print("Free apps have more total installs.")
else:
    print("Paid apps have more total installs.")
# Out:
# Free Apps - Average Rating: 4.198560100166945 | Total Installs: 146561162546
# Paid Apps - Average Rating: 4.2692913385826765 | Total Installs: 69174871
# Paid apps have a higher average rating.
# Free apps have more total installs.

# %% [markdown]
# | App Type | Average Rating | Total Installs   |
# |----------|----------------|-------------------|
# | Free     | 4.20           | 146,561,162,546   |
# | Paid     | 4.27           | 69,174,871        |
#
# - Paid apps have a higher average rating.
# - Free apps have more total installs.
#
#
# ---

# %% [markdown]
# ## **Question 21:**
# ### **What is the average app size for the top 10 most installed apps in each category?**

# %%
# Group by category and get the top 10 apps by installs
top_apps = df.groupby('category').apply(lambda x: x.nlargest(10, 'installs')).reset_index(drop=True)

# Calculate the average app size for the top 10 apps in each category
average_size = top_apps.groupby('category')['size_in_mb'].mean().reset_index()
# Change the number in head() to get more results
average_size.head(10)
# Out:
#               category  size_in_mb
# 0       ART_AND_DESIGN   24.130379
# 1    AUTO_AND_VEHICLES   24.956919
# 2               BEAUTY   21.693838
# 3  BOOKS_AND_REFERENCE   21.534596
# 4             BUSINESS   21.980757
# 5               COMICS   22.020757
# 6        COMMUNICATION   21.534596
# 7               DATING   19.774217
# 8            EDUCATION   17.960757
# 9        ENTERTAINMENT   26.220757

# %% [markdown]
# - The Entertainment category stands out as having the largest average size, which may be indicative of more complex functionalities or media content.
# - Education apps tend to be smaller in size, possibly reflecting simpler functionalities or content delivery methods.
# - Categories such as AUTO_AND_VEHICLES and ART_AND_DESIGN also have relatively high average sizes, suggesting a variety of features that require more storage.
#
#
# ---

# %% [markdown]
# ## **Question 22:**
# ### **How do app ratings differ by content rating categories (e.g., Everyone vs. Mature)?**

# %%
# Group by content rating and calculate the average rating
average_ratings = df.groupby('content_rating')['rating'].mean().reset_index()

# Rename the columns for clarity
average_ratings.columns = ['Content Rating', 'Average Rating']

# Display the average ratings by content rating category
print(average_ratings)
# Out:
#     Content Rating  Average Rating
# 0  Adults only 18+        4.300000
# 1         Everyone        4.199164
# 2     Everyone 10+        4.256117
# 3       Mature 17+        4.138479
# 4             Teen        4.245462
# 5          Unrated        4.200000

# %% [markdown]
# | Content Rating     | Average Rating |
# |--------------------|----------------|
# | Adults only 18+    | 4.300000       |
# | Everyone           | 4.199164       |
# | Everyone 10+       | 4.256117       |
# | Mature 17+         | 4.138479       |
# | Teen               | 4.245462       |
# | Unrated            | 4.200000       |
#
#
# - The data shows that apps with an `Adults only 18+` content rating have the highest average rating, followed by `Everyone 10+` and `Teen` content ratings. This indicates that apps with more mature content tend to have higher ratings.
# - The `Mature 17+` content rating has the lowest average rating, suggesting that apps with more mature content may not be as well-received by users.
# - The `Everyone` content rating has an average rating of 4.20, indicating that apps with content suitable for all ages are generally well-received by users.
# - The `Unrated` content rating has an average rating of 4.20, indicating that apps with an unknown content rating may also be well-received by users.
#
# ---
# ---

# %% [markdown]
# ### **16_App Insights Overview 📈📊**
# - We looked closely at the `Google App Store data` and found many interesting things. The data was mostly clear and trustworthy. We asked a lot of questions and got detailed answers that we can’t wait to share!
#
# ---
#
# ### **Q1: Which category has the highest number of apps?**
# **✨ A1:** The category with the highest number of apps is **FAMILY**, totaling **1,939 apps**.
#
# ---
#
# ### **Q2: Which category has the highest number of installs?**
# **✨ A2:** The category with the highest number of installs is **GAME**, with a staggering **21.51 million installs**.
#
# ---
#
# ### **Q3: Which category has the highest number of reviews?**
# **✨ A3:** The category with the highest number of reviews is **GAME**, boasting an impressive **1,415,536,650 reviews**.
#
# ---
#
# ### **Q4: Which category has the highest rating?**
# **✨ A4:** The category with the highest rating is **EVENTS**, achieving an average rating of **4.40**.
#
# ---
#
# ### **Q5: Which type of apps are more prevalent in the dataset, free or paid?**
# **✨ A5:** An overwhelming **92.61%** of the apps are free, while only **7.39%** are paid—showing that free apps dominate the dataset.
#
# ---
#
# ### **Q6: Which content rating is most popular in installs?**
# **✨ A6:** The most popular content rating in terms of installs is **Everyone**, with a total of **8,372 installs**.
#
# ---
#
# ### **Q7: How many apps are there in the "Everyone" content rating?**
# **✨ A7:** There are **8,714 apps** categorized under **Everyone**, featuring a diverse range of options.
#
# ---
#
# ### **Q8: What are the top 5 rated free apps?**
# **✨ A8:** The top 5 rated free apps are:
# - **WRPSOT**
# - **Ft. Min School - Audio Exchange**
# - **Master Mix Pro**
# - **DH-UFO**
# - **DV-ASSIST**
#
# ---
#
# ### **Q9: What are the top 5 free apps with the highest number of reviews?**
# **✨ A9:** The free apps with the highest number of reviews include:
# - **Facebook**
# - **WhatsApp Messenger**
# - **Instagram**
#
# ---
#
# ### **Q10: What are the top 5 paid apps with the highest number of reviews?**
# **✨ A10:** The top 5 paid apps with the highest number of reviews are:
# - **Minecraft**
# - **Hitman Sniper**
# - **Grand Theft Auto**
# - **Bloons TD 5**
#
# ---
#
# ### **Q11: What are the top 5 rated paid apps?**
# **✨ A11:** The top 5 rated paid apps are:
# - **Mu.F.O**
# - **FO Bixby**
# - **Morse Player**
# - **Santa's Monster Shootout DX**
# - **Chronolink DX**
#
# ---
#
# ### **Q12: What is the correlation between the number of reviews and app ratings?**
# **✨ A12:** The correlation of **0.06** indicates a weak relationship between the number of reviews and app ratings.
#
# ---
#
# ### **Q13: How does app size (in MB) affect user ratings?**
# **✨ A13:** The correlation of **0.06** suggests a negligible relationship between app size and user ratings.
#
# ---
#
# ### **Q14: Which apps have the highest ratings but the lowest number of installs?**
# **✨ A14:** Several apps boast a perfect rating of **5.0** but have very low install counts, with the highest being just **5 installs**.
#
# ---
#
# ### **Q15: How does the Android version requirement affect app ratings?**
# **✨ A15:** App ratings tend to improve with higher Android version requirements, peaking around versions **2.0** and **2.2**, indicating that apps requiring more recent versions may enhance user experience.
#
# ---
#
# ### **Q16: What is the average size in megabytes of apps for different age groups?**
# **✨ A16:** The average app sizes are:
# - **Adults:** **22.48 MB**
# - **Everyone:** **19.38 MB**
# - **Everyone 10+:** **37.04 MB**
# - **Teen:** **29.19 MB**
# - **Unrated:** **4.45 MB**
#
# ---
#
# ### **Q17: How do app prices affect their ratings?**
# **✨ A17:** The correlation of **-0.02** indicates that app prices have little to no impact on their ratings.
#
# ---
#
# ### **Q18: Are free apps rated higher than paid ones?**
# **✨ A18:** The difference in average ratings is approximately **0.07**, indicating that, on average, paid apps are rated slightly higher than free apps.
#
# ---
#
# ### **Q19: Which genres have the highest and lowest ratings, and why?**
# **✨ A19:** **Board; Pretend Play** has the highest rating at **4.8**, while **Parenting; Brain Games** has the lowest at **3.8**, likely due to varying user engagement and expectations.
#
# ---
#
# ### **Q20: Between free and paid apps, which type has a higher average rating and more installs?**
# **✨ A20:** Paid apps have a higher average rating, while free apps have more total installs.
#
# ---
#
# ### **Q21: What is the average app size for the top 10 most installed apps in each category?**
# **✨ A21:** The average app sizes for the top 10 most installed apps range from **17.96 MB** in Education to **26.22 MB** in Entertainment.
#
# ---
#
# ### **Q22: How do app ratings differ by content rating categories (e.g., Everyone vs. Mature)?**
# **✨ A22:** App ratings by content rating categories show that **Adults only 18+** has the highest average rating at **4.30**, while **Mature 17+** has the lowest at **4.14**.
#
# ---
# ---

# %% [markdown]
# Thank you so much for checking out this notebook with me! 🙌 Your support means everything, and I couldn't have made it this far without you. As I continue my journey in data science and machine learning, I’d love your ongoing support and encouragement. Together, we can truly make a difference in the world of data! 🌍✨
#
# If you found this notebook helpful, please give it an upvote! 👍 Your support inspires me to keep exploring new possibilities in this field. Thank you for being such a wonderful part of this amazing community! 🙏🌟

# %% [markdown]
# **Get in Touch with the Author😎**

# %% [markdown]
# <a href="mailto:hazrathussainpak99@gmail.com">
#   <img src="https://cdn4.iconfinder.com/data/icons/social-media-logos-6/512/112-gmail_email_mail-512.png" alt="Email" style="width: 33px; height: 33px;">
# </a>
#
#
#
#  <a href="https://www.linkedin.com/feed/">
#   <img src="https://cdn1.iconfinder.com/data/icons/logotypes/32/circle-linkedin-512.png" alt="Linkedin" style="width: 34px; height: 34px;">
# </a>
#
#
#   <a href="https://www.kaggle.com/hussain99">
#   <img src="https://upload.wikimedia.org/wikipedia/commons/7/7c/Kaggle_logo.png?20140912155123" alt="Kaggle" style="width: 35px; height: 35px;">
# </a>
#
#
#   <a href="https://github.com/dashboard">
#   <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png" alt="Github" style="width: 30px; height: 35px;">
# </a>
